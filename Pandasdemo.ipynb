# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data_analysis/data/survey_results_public.csv',index_col='ResponseId')
schema_df = pd.read_csv('data_analysis/data/survey_results_schema.csv', index_col = 'qname')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
df.rename(columns = {'ConvertedCompYearly':'SalaryUSD'},inplace=True)

# %%
df['SalaryUSD']
# Out:
# ResponseId
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 65433   NaN
# 65434   NaN
# 65435   NaN
# 65436   NaN
# 65437   NaN
# Name: SalaryUSD, Length: 65437, dtype: float64

# %%
df['RemoteWork']
# Out:
# ResponseId
# 1                                      Remote
# 2                                      Remote
# 3                                      Remote
# 4                                         NaN
# 5                                         NaN
#                          ...
# 65433                                  Remote
# 65434                                  Remote
# 65435                               In-person
# 65436    Hybrid (some remote, some in-person)
# 65437                                     NaN
# Name: RemoteWork, Length: 65437, dtype: object

# %%
df['RemoteWork'] = df['RemoteWork'].map({'Remote': True, 'In-person':False})

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time       True  Apples
# 2           Employed, full-time       True  Apples
# ...

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2        Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 4        C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                  C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 6        Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 11                                  JavaScript;Python;Ruby
#                                ...
# 65422                       Bash/Shell (all shells);Python
# 65428                                    MATLAB;Python;SQL
# 65432    Bash/Shell (all shells);C;C#;C++;Delphi;Groovy...
# 65436             C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65437     C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 30795, dtype: object

# %%
filt
# Out:
# ResponseId
# 1        False
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 65433    False
# 65434    False
# 65435    False
# 65436     True
# 65437     True
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: bool

# %%
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 11          I used to be a developer by profession, but no...
# ...                                                       ...
# 65422                          I am a developer by profession
# 65428       I am not primarily a developer, but I write co...
# 65432                          I am a developer by profession
# 65436                          I am a developer by profession
# 65437                             I code primarily as a hobby
#
#                            Age  \
# ResponseId
# 2              35-44 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# 11             35-44 years old
# ...

# %%
schema_df
# Out:
#                     qid                                           question  \
# qname
# MainBranch         QID2  Which of the following options best describes ...
# Age              QID127                                 What is your age?*
# Employment       QID296  Which of the following best describes your cur...
# RemoteWork       QID308  Which best describes your current work situation?
# Check            QID341  Just checking to make sure you are paying atte...
# ...                 ...                                                ...
# JobSatPoints_7   QID337  Learning and using new technology, including p...
# JobSatPoints_8   QID337  Designing and building environments, databases...
# JobSatPoints_9   QID337  Being a power user of a tool, developer langua...
# JobSatPoints_10  QID337       Working with new and/or top-quality hardware
# JobSatPoints_11  QID337  A well-staffed/sourced internal network that m...
#
#                 force_resp type selector
# qname
# ...

# %%
df.shape
# Out:
# (65437, 113)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65437 entries, 1 to 65437
# Columns: 113 entries, MainBranch to JobSat
# dtypes: float64(13), object(100)
# memory usage: 56.9+ MB

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time       True  Apples
# 2           Employed, full-time       True  Apples
# ...

# %%
schema_df = pd.read_csv('data_analysis/data/survey_results_schema.csv')

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time       True  Apples
# 2           Employed, full-time       True  Apples
# 3           Employed, full-time       True  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
df.shape
# Out:
# (65437, 113)

# %%
# To see all columns
df.columns
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'SalaryUSD', 'JobSat'],
#       dtype='object', length=113)

# %%
df['EdLevel']
# Out:
# ResponseId
# 1                                Primary/elementary school
# 2             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        Some college/university study without earning ...
# 5        Secondary school (e.g. American high school, G...
#                                ...
# 65433         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65434                                                  NaN
# 65435         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65436    Secondary school (e.g. American high school, G...
# 65437                                                  NaN
# Name: EdLevel, Length: 65437, dtype: object

# %%
df['Age']
# Out:
# ResponseId
# 1        Under 18 years old
# 2           35-44 years old
# 3           45-54 years old
# 4           18-24 years old
# 5           18-24 years old
#                 ...
# 65433       18-24 years old
# 65434       25-34 years old
# 65435       25-34 years old
# 65436       18-24 years old
# 65437       18-24 years old
# Name: Age, Length: 65437, dtype: object

# %%
df['RemoteWork']
# Out:
# ResponseId
# 1         True
# 2         True
# 3         True
# 4          NaN
# 5          NaN
#          ...
# 65433     True
# 65434     True
# 65435    False
# 65436      NaN
# 65437      NaN
# Name: RemoteWork, Length: 65437, dtype: object

# %%
df['RemoteWork']
# Out:
# ResponseId
# 1         True
# 2         True
# 3         True
# 4          NaN
# 5          NaN
#          ...
# 65433     True
# 65434     True
# 65435    False
# 65436      NaN
# 65437      NaN
# Name: RemoteWork, Length: 65437, dtype: object

# %%
df.loc[1]
# Out:
# MainBranch         I am a developer by profession
# Age                            Under 18 years old
# Employment                    Employed, full-time
# RemoteWork                                   True
# Check                                      Apples
#                                 ...
# JobSatPoints_11                               NaN
# SurveyLength                                  NaN
# SurveyEase                                    NaN
# SalaryUSD                                     NaN
# JobSat                                        NaN
# Name: 1, Length: 113, dtype: object

# %%
df.loc[65432, 'RemoteWork']
# Out:
# nan

# %%
df.loc[0:4, 'RemoteWork':'LearnCode']
# Out:
#            RemoteWork   Check  \
# ResponseId
# 1                True  Apples
# 2                True  Apples
# 3                True  Apples
# 4                 NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
#
#                                                     LearnCode
# ResponseId
# 1                                      Books / Physical media
# ...

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
schema_df.sort_index()
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
#sort by Country
df.sort_values(by = ['Country', 'SalaryUSD'], ascending = [True, False], inplace = True)

# %%
df['Country'].head()
# Out:
# ResponseId
# 39346    Afghanistan
# 37549    Afghanistan
# 14673    Afghanistan
# 6942     Afghanistan
# 1566     Afghanistan
# Name: Country, dtype: object

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# ResponseId
# 39346       Afghanistan    20000.0
# 37549       Afghanistan    11512.0
# 14673       Afghanistan     8634.0
# 6942        Afghanistan     6907.0
# 1566        Afghanistan     5940.0
# 14613       Afghanistan     3597.0
# 1241        Afghanistan     3279.0
# 9825        Afghanistan      719.0
# 38003       Afghanistan       83.0
# 12281       Afghanistan       14.0
# 22246       Afghanistan        1.0
# 25201       Afghanistan        1.0
# 1328        Afghanistan        NaN
# 1378        Afghanistan        NaN
# 2138        Afghanistan        NaN
# 3823        Afghanistan        NaN
# 7690        Afghanistan        NaN
# 8815        Afghanistan        NaN
# 15329       Afghanistan        NaN
# 17375       Afghanistan        NaN
# 17567       Afghanistan        NaN
# 18321       Afghanistan        NaN
# 18723       Afghanistan        NaN
# 25712       Afghanistan        NaN
# 28559       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 15838    16256603.0
# 12724    13818022.0
# 28380     9000000.0
# 17594     6340564.0
# 17673     4936778.0
# 19268     3367716.0
# 23695     2584118.0
# 33721     2237846.0
# 34524     2153432.0
# 13764     2048046.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 15838       I am a developer by profession  25-34 years old
# 12724       I am a developer by profession  25-34 years old
# 28380       I am a developer by profession  18-24 years old
# 17594       I am a developer by profession  35-44 years old
# 17673       I am a developer by profession  25-34 years old
# 19268       I am a developer by profession  25-34 years old
# 23695       I am a developer by profession  18-24 years old
# 33721       I am a developer by profession  25-34 years old
# 34524       I am a developer by profession  18-24 years old
# 13764       I am a developer by profession  35-44 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 15838       Independent contractor, freelancer, or self-em...      False
# 12724       Employed, full-time;Independent contractor, fr...        NaN
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  \
# ResponseId
# 22246                          I am a developer by profession
# 25201       I am not primarily a developer, but I write co...
# 6103                           I am a developer by profession
# 3891                           I am a developer by profession
# 26674                          I am a developer by profession
# 40354                          I am a developer by profession
# 36311                          I am a developer by profession
# 36371                          I am a developer by profession
# 24248                          I am a developer by profession
# 5070                           I am a developer by profession
#
#                           Age  \
# ResponseId
# 22246       65 years or older
# 25201         18-24 years old
# 6103          25-34 years old
# 3891          25-34 years old
# 26674         25-34 years old
# 40354         25-34 years old
# 36311         25-34 years old
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# ResponseId
# 39346    20000.0
# 37549    11512.0
# 14673     8634.0
# 6942      6907.0
# 1566      5940.0
# 14613     3597.0
# 1241      3279.0
# 9825       719.0
# 38003       83.0
# 12281       14.0
# 22246        1.0
# 25201        1.0
# 1328         NaN
# 1378         NaN
# 2138         NaN
# Name: SalaryUSD, dtype: float64

# %%
#Calculating median value of Salary
df['SalaryUSD'].median()
# Out:
# 65000.0

# %%
df
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 39346       I am a developer by profession  25-34 years old
# 37549       I am a developer by profession  25-34 years old
# 14673       I am a developer by profession  25-34 years old
# 6942        I am a developer by profession  25-34 years old
# 1566        I am a developer by profession  25-34 years old
# ...                                    ...              ...
# 65431                I am learning to code  18-24 years old
# 65433       I am a developer by profession  18-24 years old
# 65434       I am a developer by profession  25-34 years old
# 65435       I am a developer by profession  25-34 years old
# 65437          I code primarily as a hobby  18-24 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 39346       Employed, full-time;Independent contractor, fr...       True
# ...

# %%
df.describe()
# Out:
#            CompTotal       WorkExp  JobSatPoints_1  JobSatPoints_4  \
# count   3.374000e+04  29658.000000    29324.000000    29393.000000
# mean   2.963841e+145     11.466957       18.581094        7.522140
# std    5.444117e+147      9.168709       25.966221       18.422661
# min     0.000000e+00      0.000000        0.000000        0.000000
# 25%     6.000000e+04      4.000000        0.000000        0.000000
# 50%     1.100000e+05      9.000000       10.000000        0.000000
# 75%     2.500000e+05     16.000000       22.000000        5.000000
# max    1.000000e+150     50.000000      100.000000      100.000000
#
#        JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# count    29411.000000    29450.000000     29448.00000    29456.000000
# mean        10.060857       24.343232        22.96522       20.278165
# std         21.833836       27.089360        27.01774       26.108110
# min          0.000000        0.000000         0.00000        0.000000
# ...

# %%
df['SalaryUSD'].count()
# Out:
# 23435

# %%
df['RemoteWork']
# Out:
# ResponseId
# 39346     True
# 37549     True
# 14673      NaN
# 6942     False
# 1566     False
#          ...
# 65431    False
# 65433     True
# 65434     True
# 65435    False
# 65437      NaN
# Name: RemoteWork, Length: 65437, dtype: object

# %%
# Using value counts for Binary Answers
df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# True     20831
# False    10960
# Name: count, dtype: int64

# %%
df['AIThreat']
# Out:
# ResponseId
# 39346    I'm not sure
# 37549    I'm not sure
# 14673              No
# 6942               No
# 1566     I'm not sure
#              ...
# 65431              No
# 65433              No
# 65434             NaN
# 65435             NaN
# 65437             NaN
# Name: AIThreat, Length: 65437, dtype: object

# %%
df['AIThreat'].value_counts()
# Out:
# AIThreat
# No              30423
# I'm not sure     8878
# Yes              5388
# Name: count, dtype: int64

# %%
#grouping in pandas
# Split, Apply Function, Combine Results

# %%
df['Country']
# Out:
# ResponseId
# 39346    Afghanistan
# 37549    Afghanistan
# 14673    Afghanistan
# 6942     Afghanistan
# 1566     Afghanistan
#             ...
# 65431            NaN
# 65433            NaN
# 65434            NaN
# 65435            NaN
# 65437            NaN
# Name: Country, Length: 65437, dtype: object

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
#                                                         ...
# Papua New Guinea                                            1
# Niger                                                       1
# Nauru                                                       1
# Micronesia, Federated States of...                          1
# Lesotho                                                     1
# Name: count, Length: 185, dtype: int64

# %%
#data frame group by object
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States of America')
# Out:
# /var/folders/8c/zvh_7xvx2bj5s1y97vp530vr0000gn/T/ipykernel_2329/636347133.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('United States of America')
#                                                    MainBranch  \
# ResponseId
# 36330                          I am a developer by profession
# 33001                          I am a developer by profession
# 8899                           I am a developer by profession
# 39644                          I am a developer by profession
# 19245                          I am a developer by profession
# ...                                                       ...
# 65257                          I am a developer by profession
# 65262                          I am a developer by profession
# 65269                          I am a developer by profession
# ...

# %%
country_grp.get_group('India')
# Out:
# /var/folders/8c/zvh_7xvx2bj5s1y97vp530vr0000gn/T/ipykernel_2329/421256909.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('India')
#                                                    MainBranch  \
# ResponseId
# 19268                          I am a developer by profession
# 34318                          I am a developer by profession
# 18603                          I am a developer by profession
# 9915                           I am a developer by profession
# 6706                           I am a developer by profession
# ...                                                       ...
# 65340       I am not primarily a developer, but I write co...
# 65384                                   I am learning to code
# 65414                                   I am learning to code
# ...

# %%
filt = df['Country'] == 'United States of America'
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 36330                          I am a developer by profession
# 33001                          I am a developer by profession
# 8899                           I am a developer by profession
# 39644                          I am a developer by profession
# 19245                          I am a developer by profession
# ...                                                       ...
# 65257                          I am a developer by profession
# 65262                          I am a developer by profession
# 65269                          I am a developer by profession
# 65270       I am not primarily a developer, but I write co...
# 65271                          I am a developer by profession
#
#                         Age  \
# ResponseId
# 36330       25-34 years old
# 33001       25-34 years old
# 8899        45-54 years old
# 39644       35-44 years old
# 19245       45-54 years old
# ...

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 39346       I am a developer by profession  25-34 years old
# 37549       I am a developer by profession  25-34 years old
# 14673       I am a developer by profession  25-34 years old
# 6942        I am a developer by profession  25-34 years old
# 1566        I am a developer by profession  25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 39346       Employed, full-time;Independent contractor, fr...       True
# 37549       Employed, full-time;Independent contractor, fr...       True
# 14673                                     Employed, full-time        NaN
# 6942                                      Employed, full-time      False
# 1566                                      Employed, full-time      False
#
#              Check                                   CodingActivities  \
# ResponseId
# ...

# %%
country_grp['DatabaseAdmired'].value_counts().head(50)
# Out:
# Country      DatabaseAdmired
# Afghanistan  PostgreSQL                                                                                                                                                                                                                                                                                                                                                       4
#              SQLite                                                                                                                                                                                                                                                                                                                                                           3
# ...

# %%
country_grp['DatabaseAdmired'].value_counts().loc['China']
# Out:
# DatabaseAdmired
# SQLite                           27
# MySQL                            22
# PostgreSQL                       17
# MongoDB                          10
# MySQL;Redis                       7
#                                  ..
# MongoDB;Redis                     1
# MySQL;PostgreSQL;Redis;SQLite     1
# MySQL;PostgreSQL;SQLite           1
# PostgreSQL;SQLite;Supabase        1
# Supabase                          1
# Name: count, Length: 96, dtype: int64

# %%
#median salary for employees in different countries
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               3438.0
# Albania                                  35341.0
# Algeria                                   7120.0
# Andorra                                 123517.0
# Angola                                    1754.0
#                                           ...
# Venezuela, Bolivarian Republic of...     10800.0
# Viet Nam                                 12288.5
# Yemen                                     5333.0
# Zambia                                    2280.0
# Zimbabwe                                 18000.0
# Name: SalaryUSD, Length: 185, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 73036.0

# %%
country_grp['SalaryUSD'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             3438.0    5057.250000
# Albania                                35341.0   39207.545455
# Algeria                                 7120.0   91836.700000
# Andorra                               123517.0  123517.000000
# Angola                                  1754.0    1366.333333
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...   10800.0   20137.371429
# Viet Nam                               12288.5   18803.281250
# Yemen                                   5333.0   16498.400000
# Zambia                                  2280.0   17054.400000
# Zimbabwe                               18000.0   29681.818182
#
# [185 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Canada']
# Out:
# median     87231.00000
# mean      102348.69116
# Name: Canada, dtype: float64

# %%
#list of people who have worked with python in india
filt = df['Country'] == 'India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 2128

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
# What percent of people from each country know Python ?
country_respondents = df['Country'].value_counts()

# %%
#Total number of people from each country who responded to this survey
country_respondents

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis = 'columns', sort = False)
python_df

# %%
python_df.rename(columns={'count':'NumRespondents', 'LanguageHaveWorkedWith':'NumKnowsPython'}, inplace = True)

# %%
python_df

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100

# %%
python_df

# %%
python_df.sort_values(by = 'PctKnowsPython', ascending = False, inplace = True)

# %%
python_df

# %%
python_df.loc['Japan']

# %%
df

# %%
df.head()

# %%
df['YearsCode'].head(10)

# %%
#all unique values of the column
df['YearsCode'].unique()

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace = True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace = True)

# %%
df['YearsCode'].unique()

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
# mean of YearsCode column
df['YearsCode'].mean()

# %%
df['YearsCode'].median()

# %%
df.head()

# %%
filt = (df['Country']== 'India')

# %%
india_df = df.loc[filt]

# %%
india_df.head()

# %%
india_df.to_csv('data_analysis/data/modified_csv')

# %%
india_df.to_csv('data_analysis/data/modified.tsv', sep='\t')

# %%
india_df.to_excel('data_analysis/data/modified.xlsx')

# %%
test = pd.read_excel('data_analysis/data/modified.xlsx', index_col = 'ResponseId')

# %%
test.head()

# %%
india_df.to_json('data_analysis/data/modified.json', orient = 'records', lines = True)

# %%
test = pd.rea
